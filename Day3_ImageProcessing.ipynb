# %% [markdown]
# <a href="https://colab.research.google.com/github/GlyphicGuy/ML-MiniProjects/blob/main/Day3_ImageProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
img = Image.open('/content/sample-pic.jpg')

# %%
img.size
# Out:
# (1024, 1024)

# %%
rimg = img.resize((30,40))

# %%
rimg
# Out:
# <PIL.Image.Image image mode=RGB size=30x40>

# %%
rimg.resize((3488,4640))
# Out:
# <PIL.Image.Image image mode=RGB size=3488x4640>

# %%
cimg = rimg.crop((0,0,20,30))
cimg
# Out:
# <PIL.Image.Image image mode=RGB size=20x30>

# %%
boximg = Image.new('RGB',(200,200),color='black')
boximg
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
# and many more thing, explore in the PIL library
#home work
